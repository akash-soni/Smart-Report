# %%
from langchain_community.document_loaders import WikipediaLoader
import wikipedia

wikipedia.set_user_agent("MyApp/1.0 (https://example.com)")

# %%
wikipedia.set_user_agent("Mozilla/5.0")

# %%
docs = WikipediaLoader(query="modern indian history", load_max_docs=2).load()
len(docs)
# Out:
# 2

# %%
import requests

requests.get(
    "https://en.wikipedia.org",
    headers={"User-Agent": "Mozilla/5.0"},
    timeout=5,
)
# Out:
# <Response [200]>

# %%
docs
# Out:
# [Document(metadata={'title': 'History of India (1947–present)', 'summary': "The history of independent India or history of Republic of India began when the country became an independent sovereign state within the British Commonwealth on 15 August 1947. Direct administration by the British, which began in 1858, affected a political and economic unification of the subcontinent. When British rule came to an end in 1947, the subcontinent was partitioned along religious lines into two separate countries—India, with a majority of Hindus, and Pakistan, with a majority of Muslims. Concurrently the Muslim-majority northwest and east of British India was separated into the Dominion of Pakistan, by the Partition of India. The partition led to a population transfer of more than 10 million people between India and Pakistan and the death of about one million people. Indian National Congress leader Jawaharlal Nehru became the first Prime Minister of India, but the leader most associated with the in
# ...
